# %%
# load libraries
import pandas as pd
import numpy as np

# %%
# # load data
# df = pd.read_csv("../output4.csv", sep=";", index_col=0)
df=pd.read_csv("../output4.csv", sep=";")

# %%
# view the data
df
# Out:
#         Employment_Types Expiry_Date  Posted_On_Behalf  \
# 0              Permanent  2023-05-08             False
# 1              Permanent  2023-05-08             False
# 2              Permanent  2023-05-08             False
# 3              Permanent  2023-05-08             False
# 4              Full Time  2023-04-22             False
# ...                  ...         ...               ...
# 1767824        Permanent  2024-04-21             False
# 1767825        Permanent  2024-04-21             False
# 1767826        Permanent  2024-04-21             False
# 1767827        Permanent  2024-04-21             False
# 1767828        Permanent  2024-04-21             False
#
#                                Job_Post_ID New_Post_Date Orig_Post_Date  \
# 0                         MCF-2023-0252866    2023-04-08     2023-03-30
# 1                         MCF-2023-0252866    2023-04-08     2023-03-30
# 2                         MCF-2023-0252866    2023-04-08     2023-03-30
# ...

# %%
df.shape
# Out:
# (1767829, 21)

# %%
 # Show all columns
pd.set_option('display.max_columns', None) 
df.head(10)
# Out:
#   Employment_Types Expiry_Date  Posted_On_Behalf       Job_Post_ID  \
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 1        Permanent  2023-05-08             False  MCF-2023-0252866
# 2        Permanent  2023-05-08             False  MCF-2023-0252866
# 3        Permanent  2023-05-08             False  MCF-2023-0273977
# 4        Full Time  2023-04-22             False  MCF-2023-0273994
# 5        Permanent  2023-05-08             False  MCF-2023-0273991
# 6        Full Time  2023-05-08             False  MCF-2023-0273976
# 7        Full Time  2023-04-22             False  MCF-2023-0273974
# 8        Full Time  2023-04-22             False  MCF-2023-0273974
# 9        Full Time  2023-04-22             False  MCF-2023-0273974
#
#   New_Post_Date Orig_Post_Date  Repost_Count  Total_Applications  Total_Views  \
# 0    2023-04-08     2023-03-30             2                   5          151
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1767829 entries, 0 to 1767828
# Data columns (total 21 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Employment_Types    object
#  1   Expiry_Date         object
#  2   Posted_On_Behalf    bool
#  3   Job_Post_ID         object
#  4   New_Post_Date       object
#  5   Orig_Post_Date      object
#  6   Repost_Count        int64
#  7   Total_Applications  int64
#  8   Total_Views         int64
#  9   Min_Yrs_Experience  int64
#  10  Vacancies           int64
#  11  Position_Level      object
#  12  Company_Name        object
#  13  Salary_Max          int64
#  14  Salary_Min          int64
#  15  Status_ID           int64
#  16  Job_Status          object
#  17  Job_Title           object
#  18  Avg_Salary          float64
#  19  Category            object
#  20  Job_Group           object
# dtypes: bool(1), float64(1), int64(8), object(11)
# memory usage: 271.4+ MB

# %%
# describe the text and string data
df.describe(include=['object'])
# Out:
#        Employment_Types Expiry_Date                        Job_Post_ID  \
# count           1767829     1767829                            1767829
# unique                8         453                            1044597
# top           Permanent  2023-07-05  RANDOM_JOB_20251115011349636339_9
# freq             854349        7398                                  5
#
#        New_Post_Date Orig_Post_Date Position_Level            Company_Name  \
# count        1767829        1767829        1767829                 1767829
# unique           431            603              9                   53151
# top       2023-06-09     2023-07-14      Executive  RECRUITPEDIA PTE. LTD.
# freq            7650           6987         426975                  106391
#
#        Job_Status   Job_Title                Category Job_Group
# count     1767829     1767829                 1767829   1767829
# unique          3      377084                      43        20
# ...

# %%
# drop column "Salary_Type" as it has only one unique value
df.drop(columns=['Salary_Type'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # drop column "Salary_Type" as it has only one unique value
# ----> 2 df.drop(columns=['Salary_Type'], inplace=True)
#
# File ~/miniconda3/envs/pds/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/pds/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# view the final dataframe and check the data types and count of non-null values
df.describe(include="all").round(1)
# Out:
#        Employment_Types Expiry_Date Posted_On_Behalf  \
# count           1767829     1767829          1767829
# unique                8         453                2
# top           Permanent  2023-07-05            False
# freq             854349        7398          1679330
# mean                NaN         NaN              NaN
# std                 NaN         NaN              NaN
# min                 NaN         NaN              NaN
# 25%                 NaN         NaN              NaN
# 50%                 NaN         NaN              NaN
# 75%                 NaN         NaN              NaN
# max                 NaN         NaN              NaN
#
#                               Job_Post_ID New_Post_Date Orig_Post_Date  \
# count                             1767829       1767829        1767829
# unique                            1044597           431            603
# top     RANDOM_JOB_20251115011349636339_9    2023-06-09     2023-07-14
# ...

# %%
# Describe "Min_Yrs_Experience" column to see the unique values and their counts
df.describe()["Min_Yrs_Experience"].round(1)
# 99.9999% quantile of "Min_Yrs_Experience" is 20, so we can filter out the rows with "Min_Yrs_Experience" greater than 20
s = df["Min_Yrs_Experience"]
print("99.9999th Pct", f"${s.quantile(0.99999):,.0f}")
# Out:
# 99.9999th Pct $61

# %%
# find the max and min values of the "Min_Yrs_Experience" column and all cresponding rows   
df[df["Min_Yrs_Experience"] == df["Min_Yrs_Experience"].max()]
# Out:
#               Employment_Types Expiry_Date  Posted_On_Behalf  \
# 664347               Full Time  2023-09-26             False
# 1767785  Internship/Attachment  2024-12-12              True
# 1767786  Internship/Attachment  2024-12-12              True
# 1767787  Internship/Attachment  2024-12-12              True
#
#                                Job_Post_ID New_Post_Date Orig_Post_Date  \
# 664347                    MCF-2023-0698710    2023-09-12     2023-09-12
# 1767785  RANDOM_JOB_20251115011346015685_0    2024-01-16     2024-01-12
# 1767786  RANDOM_JOB_20251115011346015685_0    2024-01-16     2024-01-12
# 1767787  RANDOM_JOB_20251115011346015685_0    2024-01-16     2024-01-12
#
#          Repost_Count  Total_Applications  Total_Views  Min_Yrs_Experience  \
# 664347              0                   0            1                  88
# 1767785             0                 921         1604                  88
# ...

# %%
# save the cleaned data to a new CSV file
df.to_csv("../output3.csv", sep=";", index=False)

# %%
# read the CSV file back into a dataframe, you can use the following code:
df_test_output = pd.read_csv("../data/output3.csv", sep=";", index_col=0)

# %%
# view the final dataframe and check the data types and count of non-null values
df_test_output.info()
df_test_output.describe(include="all").round(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # view the final dataframe and check the data types and count of non-null values
# ----> 2 df_test_output.info()
#       3 df_test_output.describe(include="all").round(1)
#
# NameError: name 'df_test_output' is not defined

# %%
# Display the first 10 rows of the dataframe
df_test_output.head(10)
# Out:
#                  Expiry_Date  Posted_On_Behalf       Job_Post_ID  \
# Employment_Types
# Permanent         2023-05-08             False  MCF-2023-0252866
# Permanent         2023-05-08             False  MCF-2023-0252866
# Permanent         2023-05-08             False  MCF-2023-0252866
# Permanent         2023-05-08             False  MCF-2023-0273977
# Full Time         2023-04-22             False  MCF-2023-0273994
# Permanent         2023-05-08             False  MCF-2023-0273991
# Full Time         2023-05-08             False  MCF-2023-0273976
# Full Time         2023-04-22             False  MCF-2023-0273974
# Full Time         2023-04-22             False  MCF-2023-0273974
# Full Time         2023-04-22             False  MCF-2023-0273974
#
#                  New_Post_Date Orig_Post_Date  Repost_Count  \
# Employment_Types
# Permanent           2023-04-08     2023-03-30             2
# Permanent           2023-04-08     2023-03-30             2
# ...
