# %%
# load libraries
import pandas as pd
import numpy as np

# %%
# load data
df = pd.read_csv("../data/output2.csv", sep=";", index_col=0)

# %%
# view the data
df
# Out:
#         Employment_Types Expiry_Date  Posted_On_Behalf  \
# 0              Permanent  2023-05-08             False
# 0              Permanent  2023-05-08             False
# 0              Permanent  2023-05-08             False
# 1              Permanent  2023-05-08             False
# 2              Full Time  2023-04-22             False
# ...                  ...         ...               ...
# 1048584        Permanent  2024-04-21             False
# 1048584        Permanent  2024-04-21             False
# 1048584        Permanent  2024-04-21             False
# 1048584        Permanent  2024-04-21             False
# 1048584        Permanent  2024-04-21             False
#
#                                Job_Post_ID New_Post_Date Orig_Post_Date  \
# 0                         MCF-2023-0252866    2023-04-08     2023-03-30
# 0                         MCF-2023-0252866    2023-04-08     2023-03-30
# 0                         MCF-2023-0252866    2023-04-08     2023-03-30
# 1                         MCF-2023-0273977    2023-04-08     2023-04-08
# 2                         MCF-2023-0273994    2023-04-08     2023-04-08
# ...                                    ...           ...            ...
# 1048584  RANDOM_JOB_20251115011349636339_9    2023-11-18     2023-10-28
# 1048584  RANDOM_JOB_20251115011349636339_9    2023-11-18     2023-10-28
# 1048584  RANDOM_JOB_20251115011349636339_9    2023-11-18     2023-10-28
# 1048584  RANDOM_JOB_20251115011349636339_9    2023-11-18     2023-10-28
# 1048584  RANDOM_JOB_20251115011349636339_9    2023-11-18     2023-10-28
#
#          Repost_Count  Total_Applications  Total_Views  Min_Yrs_Experience  \
# 0                   2                   5          151                   0
# 0                   2                   5          151                   0
# 0                   2                   5          151                   0
# 1                   0                   0           55                   2
# 2                   0                   7           99                   3
# ...               ...                 ...          ...                 ...
# 1048584             2                 632         3920                   5
# 1048584             2                 632         3920                   5
# 1048584             2                 632         3920                   5
# 1048584             2                 632         3920                   5
# 1048584             2                 632         3920                   5
#
#          Vacancies    Position_Level                      Company_Name  \
# 0                1         Executive               WORKSTONE PTE. LTD.
# 0                1         Executive               WORKSTONE PTE. LTD.
# 0                1         Executive               WORKSTONE PTE. LTD.
# 1                2         Executive           TRUST RECRUIT PTE. LTD.
# 2                1  Senior Executive        PU TIEN SERVICES PTE. LTD.
# ...            ...               ...                               ...
# 1048584        902     Non-executive  THALES DIS (SINGAPORE) PTE. LTD.
# 1048584        902     Non-executive  THALES DIS (SINGAPORE) PTE. LTD.
# 1048584        902     Non-executive  THALES DIS (SINGAPORE) PTE. LTD.
# 1048584        902     Non-executive  THALES DIS (SINGAPORE) PTE. LTD.
# 1048584        902     Non-executive  THALES DIS (SINGAPORE) PTE. LTD.
#
#          Salary_Max  Salary_Min Salary_Type  Status_ID Job_Status  \
# 0              2800        2000     Monthly          0     Closed
# 0              2800        2000     Monthly          0     Closed
# 0              2800        2000     Monthly          0     Closed
# 1              5500        4000     Monthly          0     Closed
# 2              4600        3800     Monthly          0     Closed
# ...             ...         ...         ...        ...        ...
# 1048584    14420727      164428     Monthly          0    Re-open
# 1048584    14420727      164428     Monthly          0    Re-open
# 1048584    14420727      164428     Monthly          0    Re-open
# 1048584    14420727      164428     Monthly          0    Re-open
# 1048584    14420727      164428     Monthly          0    Re-open
#
#                                                  Job_Title  Avg_Salary  \
# 0        Food Technologist - Clementi | Entry Level | U...      2400.0
# 0        Food Technologist - Clementi | Entry Level | U...      2400.0
# 0        Food Technologist - Clementi | Entry Level | U...      2400.0
# 1        Software Engineer (Fab Support) (Java, CIM, Up...      4750.0
# 2                                        Senior Technician      4200.0
# ...                                                    ...         ...
# 1048584                       sales and operations manager   7292577.5
# 1048584                       sales and operations manager   7292577.5
# 1048584                       sales and operations manager   7292577.5
# 1048584                       sales and operations manager   7292577.5
# 1048584                       sales and operations manager   7292577.5
#
#                             Category
# 0               Environment / Health
# 0                      Manufacturing
# 0        Sciences / Laboratory / R&D
# 1             Information Technology
# 2             Repair and Maintenance
# ...                              ...
# 1048584          Admin / Secretarial
# 1048584             Customer Service
# 1048584                  Hospitality
# 1048584   Medical / Therapy Services
# 1048584               Sales / Retail
#
# [1767829 rows x 21 columns]

# %%
df.shape
# Out:
# (1767829, 21)

# %%
 # Show all columns
pd.set_option('display.max_columns', None) 
df.head(10)
# Out:
#   Employment_Types Expiry_Date  Posted_On_Behalf       Job_Post_ID  \
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 1        Permanent  2023-05-08             False  MCF-2023-0273977
# 2        Full Time  2023-04-22             False  MCF-2023-0273994
# 3        Permanent  2023-05-08             False  MCF-2023-0273991
# 4        Full Time  2023-05-08             False  MCF-2023-0273976
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
#
#   New_Post_Date Orig_Post_Date  Repost_Count  Total_Applications  Total_Views  \
# 0    2023-04-08     2023-03-30             2                   5          151
# 0    2023-04-08     2023-03-30             2                   5          151
# 0    2023-04-08     2023-03-30             2                   5          151
# 1    2023-04-08     2023-04-08             0                   0           55
# 2    2023-04-08     2023-04-08             0                   7           99
# 3    2023-04-08     2023-04-08             0                   6          113
# 4    2023-04-08     2023-04-08             0                   3           99
# 5    2023-04-08     2023-04-08             0                   4          110
# 5    2023-04-08     2023-04-08             0                   4          110
# 5    2023-04-08     2023-04-08             0                   4          110
#
#    Min_Yrs_Experience  Vacancies    Position_Level  \
# 0                   0          1         Executive
# 0                   0          1         Executive
# 0                   0          1         Executive
# 1                   2          2         Executive
# 2                   3          1  Senior Executive
# 3                   8          1  Senior Executive
# 4                   2          3     Non-executive
# 5                   1          3  Junior Executive
# 5                   1          3  Junior Executive
# 5                   1          3  Junior Executive
#
#                        Company_Name  Salary_Max  Salary_Min Salary_Type  \
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 1           TRUST RECRUIT PTE. LTD.        5500        4000     Monthly
# 2        PU TIEN SERVICES PTE. LTD.        4600        3800     Monthly
# 3           TRUST RECRUIT PTE. LTD.       10000        5000     Monthly
# 4  EATZ CATERING SERVICES PTE. LTD.        3400        2400     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
#
#    Status_ID Job_Status                                          Job_Title  \
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 1          0     Closed  Software Engineer (Fab Support) (Java, CIM, Up...
# 2          0     Closed                                  Senior Technician
# 3          0     Closed  Senior .NET Developer (.NET Core, MVC, MVVC, S...
# 4          0     Closed                           Sales / Admin Cordinator
# 5          0     Closed                          Software Support Engineer
# 5          0     Closed                          Software Support Engineer
# 5          0     Closed                          Software Support Engineer
#
#    Avg_Salary                     Category
# 0      2400.0         Environment / Health
# 0      2400.0                Manufacturing
# 0      2400.0  Sciences / Laboratory / R&D
# 1      4750.0       Information Technology
# 2      4200.0       Repair and Maintenance
# 3      7500.0       Information Technology
# 4      2900.0          Admin / Secretarial
# 5      5000.0                   Consulting
# 5      5000.0       Information Technology
# 5      5000.0        Professional Services

# %%
# describe the text and string data
df.describe(include=['object'])
# Out:
#        Employment_Types Expiry_Date       Job_Post_ID New_Post_Date  \
# count           1767829     1767829           1767829       1767829
# unique                8         453           1044597           431
# top           Permanent  2023-07-05  MCF-2023-0261998    2023-06-09
# freq             854349        7398                 5          7650
#
#        Orig_Post_Date Position_Level            Company_Name Salary_Type  \
# count         1767829        1767829                 1767829     1767829
# unique            603              9                   53151           1
# top        2023-07-14      Executive  RECRUITPEDIA PTE. LTD.     Monthly
# freq             6987         426975                  106391     1767829
#
#        Job_Status   Job_Title                Category
# count     1767829     1767829                 1767829
# unique          3      377084                      43
# top          Open  SUPERVISOR  Information Technology
# freq      1529512        9182                  140866

# %%
# drop column "Salary_Type" as it has only one unique value
df.drop(columns=['Salary_Type'], inplace=True)

# %%
# view the final dataframe and check the data types and count of non-null values
df.describe(include="all").round(1)
# Out:
#        Employment_Types Expiry_Date Posted_On_Behalf       Job_Post_ID  \
# count           1767829     1767829          1767829           1767829
# unique                8         453                2           1044597
# top           Permanent  2023-07-05            False  MCF-2023-0261998
# freq             854349        7398          1679330                 5
# mean                NaN         NaN              NaN               NaN
# std                 NaN         NaN              NaN               NaN
# min                 NaN         NaN              NaN               NaN
# 25%                 NaN         NaN              NaN               NaN
# 50%                 NaN         NaN              NaN               NaN
# 75%                 NaN         NaN              NaN               NaN
# max                 NaN         NaN              NaN               NaN
#
#        New_Post_Date Orig_Post_Date  Repost_Count  Total_Applications  \
# count        1767829        1767829     1767829.0           1767829.0
# unique           431            603           NaN                 NaN
# top       2023-06-09     2023-07-14           NaN                 NaN
# freq            7650           6987           NaN                 NaN
# mean             NaN            NaN           0.1                 2.1
# std              NaN            NaN           0.3                10.9
# min              NaN            NaN           0.0                 0.0
# 25%              NaN            NaN           0.0                 0.0
# 50%              NaN            NaN           0.0                 0.0
# 75%              NaN            NaN           0.0                 1.0
# max              NaN            NaN           2.0              1342.0
#
#         Total_Views  Min_Yrs_Experience  Vacancies Position_Level  \
# count     1767829.0           1767829.0  1767829.0        1767829
# unique          NaN                 NaN        NaN              9
# top             NaN                 NaN        NaN      Executive
# freq            NaN                 NaN        NaN         426975
# mean           26.2                 2.6        2.8            NaN
# std            82.7                 2.5       12.2            NaN
# min             0.0                 0.0        1.0            NaN
# 25%             1.0                 1.0        1.0            NaN
# 50%             4.0                 2.0        1.0            NaN
# 75%            16.0                 3.0        2.0            NaN
# max          8190.0                88.0      999.0            NaN
#
#                   Company_Name  Salary_Max  Salary_Min  Status_ID Job_Status  \
# count                  1767829   1767829.0   1767829.0  1767829.0    1767829
# unique                   53151         NaN         NaN        NaN          3
# top     RECRUITPEDIA PTE. LTD.         NaN         NaN        NaN       Open
# freq                    106391         NaN         NaN        NaN    1529512
# mean                       NaN      5762.8      3708.5        0.0        NaN
# std                        NaN     71928.8      3121.8        0.0        NaN
# min                        NaN         1.0         1.0        0.0        NaN
# 25%                        NaN      3200.0      2500.0        0.0        NaN
# 50%                        NaN      4500.0      3000.0        0.0        NaN
# 75%                        NaN      6000.0      4000.0        0.0        NaN
# max                        NaN  25330000.0    350000.0        0.0        NaN
#
#          Job_Title  Avg_Salary                Category
# count      1767829   1767829.0                 1767829
# unique      377084         NaN                      43
# top     SUPERVISOR         NaN  Information Technology
# freq          9182         NaN                  140866
# mean           NaN      4735.6                     NaN
# std            NaN     36432.7                     NaN
# min            NaN         1.0                     NaN
# 25%            NaN      2855.0                     NaN
# 50%            NaN      3750.0                     NaN
# 75%            NaN      5250.0                     NaN
# max            NaN  12666400.0                     NaN

# %%
# Describe "Min_Yrs_Experience" column to see the unique values and their counts
df.describe()["Min_Yrs_Experience"].round(1)
# Out:
# count    1767829.0
# mean           2.6
# std            2.5
# min            0.0
# 25%            1.0
# 50%            2.0
# 75%            3.0
# max           88.0
# Name: Min_Yrs_Experience, dtype: float64

# %%
# find the max and min values of the "Min_Yrs_Experience" column and all cresponding rows   
df[df["Min_Yrs_Experience"] == df["Min_Yrs_Experience"].max()]
# Out:
#               Employment_Types Expiry_Date  Posted_On_Behalf  \
# 398461               Full Time  2023-09-26             False
# 1048575  Internship/Attachment  2024-12-12              True
# 1048575  Internship/Attachment  2024-12-12              True
# 1048575  Internship/Attachment  2024-12-12              True
#
#                                Job_Post_ID New_Post_Date Orig_Post_Date  \
# 398461                    MCF-2023-0698710    2023-09-12     2023-09-12
# 1048575  RANDOM_JOB_20251115011346015685_0    2024-01-16     2024-01-12
# 1048575  RANDOM_JOB_20251115011346015685_0    2024-01-16     2024-01-12
# 1048575  RANDOM_JOB_20251115011346015685_0    2024-01-16     2024-01-12
#
#          Repost_Count  Total_Applications  Total_Views  Min_Yrs_Experience  \
# 398461              0                   0            1                  88
# 1048575             0                 921         1604                  88
# 1048575             0                 921         1604                  88
# 1048575             0                 921         1604                  88
#
#          Vacancies     Position_Level                       Company_Name  \
# 398461           3            Manager  NEW AMEERAH FOOD CHAINS PTE. LTD.
# 1048575        579  Middle Management       BOND CAPITAL GROUP PTE. LTD.
# 1048575        579  Middle Management       BOND CAPITAL GROUP PTE. LTD.
# 1048575        579  Middle Management       BOND CAPITAL GROUP PTE. LTD.
#
#          Salary_Max  Salary_Min  Status_ID Job_Status  \
# 398461         5000        3000          0       Open
# 1048575     6142101      107908          0     Closed
# 1048575     6142101      107908          0     Closed
# 1048575     6142101      107908          0     Closed
#
#                            Job_Title  Avg_Salary  \
# 398461               STORE ASSISTANT      4000.0
# 1048575  Senior Manager - Operations   3125004.5
# 1048575  Senior Manager - Operations   3125004.5
# 1048575  Senior Manager - Operations   3125004.5
#
#                                  Category
# 398461                Admin / Secretarial
# 1048575  Accounting / Auditing / Taxation
# 1048575               Admin / Secretarial
# 1048575         Building and Construction

# %%
# save the cleaned data to a new CSV file
df.to_csv("../data/output3.csv", sep=";", index=False)

# %%
# read the CSV file back into a dataframe, you can use the following code:
df_test_output = pd.read_csv("../data/output3.csv", sep=";", index_col=0)

# %%
# view the final dataframe and check the data types and count of non-null values
df_test_output.info()
df_test_output.describe(include="all").round(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1767829 entries, Permanent to Permanent
# Data columns (total 19 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Expiry_Date         object
#  1   Posted_On_Behalf    bool
#  2   Job_Post_ID         object
#  3   New_Post_Date       object
#  4   Orig_Post_Date      object
#  5   Repost_Count        int64
#  6   Total_Applications  int64
#  7   Total_Views         int64
#  8   Min_Yrs_Experience  int64
#  9   Vacancies           int64
#  10  Position_Level      object
#  11  Company_Name        object
#  12  Salary_Max          int64
#  13  Salary_Min          int64
#  14  Status_ID           int64
#  15  Job_Status          object
#  16  Job_Title           object
#  17  Avg_Salary          float64
#  18  Category            object
# dtypes: bool(1), float64(1), int64(8), object(9)
# memory usage: 257.9+ MB
#        Expiry_Date Posted_On_Behalf       Job_Post_ID New_Post_Date  \
# count      1767829          1767829           1767829       1767829
# unique         453                2           1044597           431
# top     2023-07-05            False  MCF-2023-0261998    2023-06-09
# freq          7398          1679330                 5          7650
# mean           NaN              NaN               NaN           NaN
# std            NaN              NaN               NaN           NaN
# min            NaN              NaN               NaN           NaN
# 25%            NaN              NaN               NaN           NaN
# 50%            NaN              NaN               NaN           NaN
# 75%            NaN              NaN               NaN           NaN
# max            NaN              NaN               NaN           NaN
#
#        Orig_Post_Date  Repost_Count  Total_Applications  Total_Views  \
# count         1767829     1767829.0           1767829.0    1767829.0
# unique            603           NaN                 NaN          NaN
# top        2023-07-14           NaN                 NaN          NaN
# freq             6987           NaN                 NaN          NaN
# mean              NaN           0.1                 2.1         26.2
# std               NaN           0.3                10.9         82.7
# min               NaN           0.0                 0.0          0.0
# 25%               NaN           0.0                 0.0          1.0
# 50%               NaN           0.0                 0.0          4.0
# 75%               NaN           0.0                 1.0         16.0
# max               NaN           2.0              1342.0       8190.0
#
#         Min_Yrs_Experience  Vacancies Position_Level            Company_Name  \
# count            1767829.0  1767829.0        1767829                 1767829
# unique                 NaN        NaN              9                   53151
# top                    NaN        NaN      Executive  RECRUITPEDIA PTE. LTD.
# freq                   NaN        NaN         426975                  106391
# mean                   2.6        2.8            NaN                     NaN
# std                    2.5       12.2            NaN                     NaN
# min                    0.0        1.0            NaN                     NaN
# 25%                    1.0        1.0            NaN                     NaN
# 50%                    2.0        1.0            NaN                     NaN
# 75%                    3.0        2.0            NaN                     NaN
# max                   88.0      999.0            NaN                     NaN
#
#         Salary_Max  Salary_Min  Status_ID Job_Status   Job_Title  Avg_Salary  \
# count    1767829.0   1767829.0  1767829.0    1767829     1767829   1767829.0
# unique         NaN         NaN        NaN          3      377084         NaN
# top            NaN         NaN        NaN       Open  SUPERVISOR         NaN
# freq           NaN         NaN        NaN    1529512        9182         NaN
# mean        5762.8      3708.5        0.0        NaN         NaN      4735.6
# std        71928.8      3121.8        0.0        NaN         NaN     36432.7
# min            1.0         1.0        0.0        NaN         NaN         1.0
# 25%         3200.0      2500.0        0.0        NaN         NaN      2855.0
# 50%         4500.0      3000.0        0.0        NaN         NaN      3750.0
# 75%         6000.0      4000.0        0.0        NaN         NaN      5250.0
# max     25330000.0    350000.0        0.0        NaN         NaN  12666400.0
#
#                       Category
# count                  1767829
# unique                      43
# top     Information Technology
# freq                    140866
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN

# %%
# Display the first 10 rows of the dataframe
df_test_output.head(10)
# Out:
#                  Expiry_Date  Posted_On_Behalf       Job_Post_ID  \
# Employment_Types
# Permanent         2023-05-08             False  MCF-2023-0252866
# Permanent         2023-05-08             False  MCF-2023-0252866
# Permanent         2023-05-08             False  MCF-2023-0252866
# Permanent         2023-05-08             False  MCF-2023-0273977
# Full Time         2023-04-22             False  MCF-2023-0273994
# Permanent         2023-05-08             False  MCF-2023-0273991
# Full Time         2023-05-08             False  MCF-2023-0273976
# Full Time         2023-04-22             False  MCF-2023-0273974
# Full Time         2023-04-22             False  MCF-2023-0273974
# Full Time         2023-04-22             False  MCF-2023-0273974
#
#                  New_Post_Date Orig_Post_Date  Repost_Count  \
# Employment_Types
# Permanent           2023-04-08     2023-03-30             2
# Permanent           2023-04-08     2023-03-30             2
# Permanent           2023-04-08     2023-03-30             2
# Permanent           2023-04-08     2023-04-08             0
# Full Time           2023-04-08     2023-04-08             0
# Permanent           2023-04-08     2023-04-08             0
# Full Time           2023-04-08     2023-04-08             0
# Full Time           2023-04-08     2023-04-08             0
# Full Time           2023-04-08     2023-04-08             0
# Full Time           2023-04-08     2023-04-08             0
#
#                   Total_Applications  Total_Views  Min_Yrs_Experience  \
# Employment_Types
# Permanent                          5          151                   0
# Permanent                          5          151                   0
# Permanent                          5          151                   0
# Permanent                          0           55                   2
# Full Time                          7           99                   3
# Permanent                          6          113                   8
# Full Time                          3           99                   2
# Full Time                          4          110                   1
# Full Time                          4          110                   1
# Full Time                          4          110                   1
#
#                   Vacancies    Position_Level  \
# Employment_Types
# Permanent                 1         Executive
# Permanent                 1         Executive
# Permanent                 1         Executive
# Permanent                 2         Executive
# Full Time                 1  Senior Executive
# Permanent                 1  Senior Executive
# Full Time                 3     Non-executive
# Full Time                 3  Junior Executive
# Full Time                 3  Junior Executive
# Full Time                 3  Junior Executive
#
#                                       Company_Name  Salary_Max  Salary_Min  \
# Employment_Types
# Permanent                      WORKSTONE PTE. LTD.        2800        2000
# Permanent                      WORKSTONE PTE. LTD.        2800        2000
# Permanent                      WORKSTONE PTE. LTD.        2800        2000
# Permanent                  TRUST RECRUIT PTE. LTD.        5500        4000
# Full Time               PU TIEN SERVICES PTE. LTD.        4600        3800
# Permanent                  TRUST RECRUIT PTE. LTD.       10000        5000
# Full Time         EATZ CATERING SERVICES PTE. LTD.        3400        2400
# Full Time         BYTECENTURE CONSULTING PTE. LTD.        6000        4000
# Full Time         BYTECENTURE CONSULTING PTE. LTD.        6000        4000
# Full Time         BYTECENTURE CONSULTING PTE. LTD.        6000        4000
#
#                   Status_ID Job_Status  \
# Employment_Types
# Permanent                 0     Closed
# Permanent                 0     Closed
# Permanent                 0     Closed
# Permanent                 0     Closed
# Full Time                 0     Closed
# Permanent                 0     Closed
# Full Time                 0     Closed
# Full Time                 0     Closed
# Full Time                 0     Closed
# Full Time                 0     Closed
#
#                                                           Job_Title  \
# Employment_Types
# Permanent         Food Technologist - Clementi | Entry Level | U...
# Permanent         Food Technologist - Clementi | Entry Level | U...
# Permanent         Food Technologist - Clementi | Entry Level | U...
# Permanent         Software Engineer (Fab Support) (Java, CIM, Up...
# Full Time                                         Senior Technician
# Permanent         Senior .NET Developer (.NET Core, MVC, MVVC, S...
# Full Time                                  Sales / Admin Cordinator
# Full Time                                 Software Support Engineer
# Full Time                                 Software Support Engineer
# Full Time                                 Software Support Engineer
#
#                   Avg_Salary                     Category
# Employment_Types
# Permanent             2400.0         Environment / Health
# Permanent             2400.0                Manufacturing
# Permanent             2400.0  Sciences / Laboratory / R&D
# Permanent             4750.0       Information Technology
# Full Time             4200.0       Repair and Maintenance
# Permanent             7500.0       Information Technology
# Full Time             2900.0          Admin / Secretarial
# Full Time             5000.0                   Consulting
# Full Time             5000.0       Information Technology
# Full Time             5000.0        Professional Services
