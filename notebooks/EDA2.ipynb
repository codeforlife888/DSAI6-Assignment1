# %%
#load libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/output2.csv", sep=";", index_col=0)

# %%
df.shape
# Out:
# (1771817, 23)

# %%
# drop "categories" column
df = df.drop(columns=["categories"])

# %%
print(df.columns.tolist())
# Out:
# ['Employment_Types', 'Expiry_Date', 'Posted_On_Behalf', 'Job_Post_ID', 'New_Post_Date', 'Orig_Post_Date', 'Repost_Count', 'Total_Applications', 'Total_Views', 'Min_Yrs_Experience', 'Vacancies', 'Occupation_ID', 'Position_Level', 'Company_Name', 'Salary_Max', 'Salary_Min', 'Salary_Type', 'Status_ID', 'Job_Status', 'title', 'Avg_Salary', 'Category']

# %%
# rename columns name:
df = df.rename(columns={"employmentTypes": "Employment_Types",
                        "metadata_expiryDate": "Expiry_Date",
                        "metadata_isPostedOnBehalf" : "Posted_On_Behalf",
                        "metadata_jobPostId": "Job_Post_ID",
                        "metadata_newPostingDate": "New_Post_Date",  
                        "metadata_originalPostingDate": "Orig_Post_Date",
                        "metadata_repostCount": "Repost_Count",
                        "metadata_totalNumberJobApplication" : "Total_Applications",                     
                        "metadata_totalNumberOfView": "Total_Views",
                        "minimumYearsExperience": "Min_Yrs_Experience",
                        "numberOfVacancies": "Vacancies",
                        "occupationId": "Occupation_ID",
                        "positionLevels": "Position_Level",
                        "postedCompany_name": "Company_Name",
                        "salary_maximum" : "Salary_Max",
                        "salary_minimum" : "Salary_Min",
                        "salary_type": "Salary_Type",
                        "status_id": "Status_ID",
                        "status_jobStatus": "Job_Status",
                        "Title": "Job_Title",
                        "average_salary": "Avg_Salary",
                        "category_single": "Category",
                     })

# %%
 # Show all columns
pd.set_option('display.max_columns', None) 
df.head(10)
# Out:
#   Employment_Types Expiry_Date  Posted_On_Behalf       Job_Post_ID  \
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 1        Permanent  2023-05-08             False  MCF-2023-0273977
# 2        Full Time  2023-04-22             False  MCF-2023-0273994
# 3        Permanent  2023-05-08             False  MCF-2023-0273991
# 4        Full Time  2023-05-08             False  MCF-2023-0273976
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
#
#   New_Post_Date Orig_Post_Date  Repost_Count  Total_Applications  Total_Views  \
# 0    2023-04-08     2023-03-30             2                   5          151
# 0    2023-04-08     2023-03-30             2                   5          151
# 0    2023-04-08     2023-03-30             2                   5          151
# 1    2023-04-08     2023-04-08             0                   0           55
# 2    2023-04-08     2023-04-08             0                   7           99
# 3    2023-04-08     2023-04-08             0                   6          113
# 4    2023-04-08     2023-04-08             0                   3           99
# 5    2023-04-08     2023-04-08             0                   4          110
# 5    2023-04-08     2023-04-08             0                   4          110
# 5    2023-04-08     2023-04-08             0                   4          110
#
#    Min_Yrs_Experience  Vacancies  Occupation_ID    Position_Level  \
# 0                   0          1            NaN         Executive
# 0                   0          1            NaN         Executive
# 0                   0          1            NaN         Executive
# 1                   2          2            NaN         Executive
# 2                   3          1            NaN  Senior Executive
# 3                   8          1            NaN  Senior Executive
# 4                   2          3            NaN     Non-executive
# 5                   1          3            NaN  Junior Executive
# 5                   1          3            NaN  Junior Executive
# 5                   1          3            NaN  Junior Executive
#
#                        Company_Name  Salary_Max  Salary_Min Salary_Type  \
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 1           TRUST RECRUIT PTE. LTD.        5500        4000     Monthly
# 2        PU TIEN SERVICES PTE. LTD.        4600        3800     Monthly
# 3           TRUST RECRUIT PTE. LTD.       10000        5000     Monthly
# 4  EATZ CATERING SERVICES PTE. LTD.        3400        2400     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
#
#    Status_ID Job_Status                                              title  \
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 1          0     Closed  Software Engineer (Fab Support) (Java, CIM, Up...
# 2          0     Closed                                  Senior Technician
# 3          0     Closed  Senior .NET Developer (.NET Core, MVC, MVVC, S...
# 4          0     Closed                           Sales / Admin Cordinator
# 5          0     Closed                          Software Support Engineer
# 5          0     Closed                          Software Support Engineer
# 5          0     Closed                          Software Support Engineer
#
#    Avg_Salary                     Category
# 0      2400.0         Environment / Health
# 0      2400.0                Manufacturing
# 0      2400.0  Sciences / Laboratory / R&D
# 1      4750.0       Information Technology
# 2      4200.0       Repair and Maintenance
# 3      7500.0       Information Technology
# 4      2900.0          Admin / Secretarial
# 5      5000.0                   Consulting
# 5      5000.0       Information Technology
# 5      5000.0        Professional Services

# %%
# save the cleaned data to a new CSV file
df.to_csv("../data/cleaned_output3.csv", sep=";", index=False)

# %%
# read the CSV file back into a dataframe, you can use the following code:
df_test_output = pd.read_csv("../data/cleaned_output3.csv", sep=";", index_col=0)

# %%
# Display the first 10 rows of the dataframe
df.head(10)
# Out:
#   Employment_Types Expiry_Date  Posted_On_Behalf       Job_Post_ID  \
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 0        Permanent  2023-05-08             False  MCF-2023-0252866
# 1        Permanent  2023-05-08             False  MCF-2023-0273977
# 2        Full Time  2023-04-22             False  MCF-2023-0273994
# 3        Permanent  2023-05-08             False  MCF-2023-0273991
# 4        Full Time  2023-05-08             False  MCF-2023-0273976
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
# 5        Full Time  2023-04-22             False  MCF-2023-0273974
#
#   New_Post_Date Orig_Post_Date  Repost_Count  Total_Applications  Total_Views  \
# 0    2023-04-08     2023-03-30             2                   5          151
# 0    2023-04-08     2023-03-30             2                   5          151
# 0    2023-04-08     2023-03-30             2                   5          151
# 1    2023-04-08     2023-04-08             0                   0           55
# 2    2023-04-08     2023-04-08             0                   7           99
# 3    2023-04-08     2023-04-08             0                   6          113
# 4    2023-04-08     2023-04-08             0                   3           99
# 5    2023-04-08     2023-04-08             0                   4          110
# 5    2023-04-08     2023-04-08             0                   4          110
# 5    2023-04-08     2023-04-08             0                   4          110
#
#    Min_Yrs_Experience  Vacancies  Occupation_ID    Position_Level  \
# 0                   0          1            NaN         Executive
# 0                   0          1            NaN         Executive
# 0                   0          1            NaN         Executive
# 1                   2          2            NaN         Executive
# 2                   3          1            NaN  Senior Executive
# 3                   8          1            NaN  Senior Executive
# 4                   2          3            NaN     Non-executive
# 5                   1          3            NaN  Junior Executive
# 5                   1          3            NaN  Junior Executive
# 5                   1          3            NaN  Junior Executive
#
#                        Company_Name  Salary_Max  Salary_Min Salary_Type  \
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 0               WORKSTONE PTE. LTD.        2800        2000     Monthly
# 1           TRUST RECRUIT PTE. LTD.        5500        4000     Monthly
# 2        PU TIEN SERVICES PTE. LTD.        4600        3800     Monthly
# 3           TRUST RECRUIT PTE. LTD.       10000        5000     Monthly
# 4  EATZ CATERING SERVICES PTE. LTD.        3400        2400     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
# 5  BYTECENTURE CONSULTING PTE. LTD.        6000        4000     Monthly
#
#    Status_ID Job_Status                                              title  \
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 0          0     Closed  Food Technologist - Clementi | Entry Level | U...
# 1          0     Closed  Software Engineer (Fab Support) (Java, CIM, Up...
# 2          0     Closed                                  Senior Technician
# 3          0     Closed  Senior .NET Developer (.NET Core, MVC, MVVC, S...
# 4          0     Closed                           Sales / Admin Cordinator
# 5          0     Closed                          Software Support Engineer
# 5          0     Closed                          Software Support Engineer
# 5          0     Closed                          Software Support Engineer
#
#    Avg_Salary                     Category
# 0      2400.0         Environment / Health
# 0      2400.0                Manufacturing
# 0      2400.0  Sciences / Laboratory / R&D
# 1      4750.0       Information Technology
# 2      4200.0       Repair and Maintenance
# 3      7500.0       Information Technology
# 4      2900.0          Admin / Secretarial
# 5      5000.0                   Consulting
# 5      5000.0       Information Technology
# 5      5000.0        Professional Services
